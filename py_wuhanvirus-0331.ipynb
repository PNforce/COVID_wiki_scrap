# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd
datalist = []
datelist = []
caseslist = []
deathslist = []

def case_from_wiki(url:str): #country 0,1,2,3,4,8 is ok
    res = requests.get(url)
    soup = BeautifulSoup(res.text)
    soup = soup.select('tr',{'class':'mw-collapsible mw-collapsed'})
    
    start = False  #出現第一次
    
    for num in range(len(soup)):
        try:
            #print('start scrap, nums' + str(num))
            #soup = soup[num].select('td')
            date = soup[num].select('td',{'colspan':'2'})[0].get_text()
            #print(date)
            cases = soup[num].select('td',{'colspan':'2'})[2].get_text()
            cases = cases.split('(')[0].replace(',','')
            #print(cases)
            deaths = soup[num].select('td',{'colspan':'2'})[3].get_text()
            deaths = deaths.split('(')[0].replace(',','')
            if start and date != '⋮':
                datelist.append(date)
                caseslist.append(cases)
                deathslist.append(deaths)
            if date =='Date':
                start = True
        except:
            if start == True:
                break
            pass
    return datelist,caseslist,deathslist

def todf(datelist,caseslist,deathslist):
    df = pd.DataFrame({'date':datelist,'cases':caseslist,'deaths':deathslist})
    return df

def country_url(num):
    urllist = [
    'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_the_United_States',
    'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Italy',
    'https://en.wikipedia.org/wiki/2019%E2%80%9320_coronavirus_pandemic_in_mainland_China',
    'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Spain',
    'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_France',
    'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Iran',
    'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_the_United_Kingdom',
    'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Switzerland',
    'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Belgium',    
    ]
    url  = urllist[num]
    return url

def country_name(url):
    url.split('')
    return name

def main():

    data = case_from_wiki(urllist[0])
    df = pd.DataFrame({'date':data[0],'cases':data[1],'deaths':data[2]})
    return df

def tocsv(df,filename,path = 'c:\'):
    df.to_csv(path.format(str(filename)),na_rep='', index=True, header=false, encoding="utf-8")   #存出絕對路徑

df = main()
df
# Out:
#           date   cases deaths
# 0   2020-01-21       1
# 1   2020-01-24       2
# 2   2020-01-25       3
# 3   2020-01-26       5
# 4   2020-01-30       6
# 5   2020-01-31       7
# 6   2020-02-01       8
# 7   2020-02-02      11
# 8   2020-02-05      12
# 9   2020-02-20      14
# 10  2020-02-25      14
# 11  2020-02-26      15
# 12  2020-02-27      15
# 13  2020-02-28      19
# 14  2020-02-29      24      1
# 15  2020-03-01      42      2
# 16  2020-03-02      57      6
# 17  2020-03-03      85      9
# 18  2020-03-04     111     11
# 19  2020-03-05     175     11
# 20  2020-03-06     252     14
# 21  2020-03-07     353     19
# 22  2020-03-08     497     21
# 23  2020-03-09     645     26
# 24  2020-03-10     936     31
# 25  2020-03-11    1205     37
# 26  2020-03-12    1598     41
# 27  2020-03-13    2163     49
# 28  2020-03-14    2825     56
# 29  2020-03-15    3501     62
# 30  2020-03-16    4373     76
# 31  2020-03-17    5664     97
# 32  2020-03-18    8074    123
# ...

# %%
def a(**kwargs):
    #print(kwargs.name)
    print(kwargs['price'])
b = {'name':'ppp','price':'100'}
a(**b)
a(name = 'df',price = '234')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-07080869b441> in <module>
#       3     print(kwargs['pric'])
#       4 b = {'name':'ppp','price':'100'}
# ----> 5 a(**b)
#       6 a(name = 'df',price = '234')
#
# <ipython-input-11-07080869b441> in a(**kwargs)
#       1 def a(**kwargs):
#       2     #print(kwargs.name)
# ----> 3     print(kwargs['pric'])
#       4 b = {'name':'ppp','price':'100'}
#       5 a(**b)
#
# KeyError: 'pric'

# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd

def main_page(c_name):
    url = 'https://en.wikipedia.org/wiki/2019%E2%80%9320_coronavirus_pandemic'
    res = requests.get(url)
    soup = BeautifulSoup(res.text)

    soup = BeautifulSoup(s)
    #soup = soup.select('table')[4].select('th',{'scope':'row'})
    soup = soup.select('table')[4].select('a')
    print(len(soup))
    c_namelist = []
    c_urllist = []
    for i in range(len(soup)):
        a = soup[i].attrs['href']
        if '/wiki/2020_coronavirus_pandemic' in a :
            #print(a)
            c_namelist.append(a.split('n_')[1])
            c_urllist.append(a)
    c_dict = dict(zip(c_namelist,c_urllist))
    print(c_dict['Taiwan'])

    countrydict = {'the_United_States': '/wiki/2020_coronavirus_pandemic_in_the_United_States', 'Spain': '/wiki/2020_coronavirus_pandemic_in_Spain', 'Italy': '/wiki/2020_coronavirus_pandemic_in_Italy', 'Germany': '/wiki/2020_coronavirus_pandemic_in_Germany', 'France': '/wiki/2020_coronavirus_pandemic_in_France', 'Iran': '/wiki/2020_coronavirus_pandemic_in_Iran', 'the_United_Kingdom': '/wiki/2020_coronavirus_pandemic_in_the_United_Kingdom', 'Turkey': '/wiki/2020_coronavirus_pandemic_in_Turkey', 'Switzerland': '/wiki/2020_coronavirus_pandemic_in_Switzerland', 'Belgium': '/wiki/2020_coronavirus_pandemic_in_Belgium', 'the_Netherlands': '/wiki/2020_coronavirus_pandemic_in_the_Netherlands', 'Canada': '/wiki/2020_coronavirus_pandemic_in_Canada', 'Brazil': '/wiki/2020_coronavirus_pandemic_in_Brazil', 'Austria': '/wiki/2020_coronavirus_pandemic_in_Austria', 'Portugal': '/wiki/2020_coronavirus_pandemic_in_Portugal', 'South_Korea': '/wiki/2020_coronavirus_pandemic_in_South_Korea', 'Israel': '/wiki/2020_coronavirus_pandemic_in_Israel', 'Sweden': '/wiki/2020_coronavirus_pandemic_in_Sweden', 'Russia': '/wiki/2020_coronavirus_pandemic_in_Russia', 'Australia': '/wiki/2020_coronavirus_pandemic_in_Australia', 'Norway': '/wiki/2020_coronavirus_pandemic_in_Norway', 'the_Republic_of_Ireland': '/wiki/2020_coronavirus_pandemic_in_the_Republic_of_Ireland', 'Chile': '/wiki/2020_coronavirus_pandemic_in_Chile', 'Denmark': '/wiki/2020_coronavirus_pandemic_in_Denmark', 'the_Czech_Republic': '/wiki/2020_coronavirus_pandemic_in_the_Czech_Republic', 'Poland': '/wiki/2020_coronavirus_pandemic_in_Poland', 'India': '/wiki/2020_coronavirus_pandemic_in_India', 'Romania': '/wiki/2020_coronavirus_pandem